# %%
import torch
import matplotlib.pyplot as plt

# %%
RESULTS_ROOT = "/results/tianjunm/monaural-source-separation/experiments"

# %%
dataset_config = 't0-2s-5c'
dataset_param = '4s'
model_name = 'L2L'
model_param = 'sample'
experiment_id = '200411052729'

# %%
snapshot = torch.load(f'/results/tianjunm/monaural-source-separation/experiments/snapshots/{model_name}-{model_param}-wild-mix-{dataset_config}-{dataset_param}/{experiment_id}/best.tar')

# %%
snapshot['loss']
# Out:
# 5221.148197234623

# %%
tl_blstm = snapshot['train_losses']
vl_blstm = snapshot['val_losses']

# %%
tl_l2l[:10]
# Out:
# [5941.333940234375,
#  5365.43975703125,
#  5049.644816796875,
#  4798.996269140625,
#  4595.28137421875,
#  4498.745686328125,
#  4547.947661328125,
#  4321.3433515625,
#  4163.22608125,
#  4031.0121921875]

# %%
tl_l2l = snapshot['train_losses']
vl_l2l = snapshot['val_losses']

# %%
plt.plot(tl_blstm)
plt.plot(vl_blstm)
plt.plot(tl_l2l)
plt.plot(vl_l2l)
